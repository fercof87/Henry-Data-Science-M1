# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
hospitales = pd.read_csv('hospitales2.csv', sep=',')
hospitales.head()
# Out:
#                                            WKT   ID
# 0  POINT (-58.3775508488443 -34.6288473603881)  1.0  \
# 1  POINT (-58.4120700769456 -34.5941919726393)  2.0
# 2  POINT (-58.4027276547828 -34.5845283357505)  4.0
# 3  POINT (-58.3851559118889 -34.6394041316484)  6.0
# 4  POINT (-58.3913114406535 -34.6341535760002)  7.0
#
#                                               NOMBRE
# 0        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE  \
# 1        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
#
#                        NOM_MAP    OBJETO                    CALLE  ALTURA
# 0            HOSP. DE ELIZALDE  HOSPITAL  MANUEL A. MONTES DE OCA      40  \
# 1              HOSP. GUTIERREZ  HOSPITAL                    GALLO    1330
# 2  HOSP. ODONTOLOGICO CARRILLO  HOSPITAL    SANCHEZ DE BUSTAMANTE    2529
# ...

# %%
hospitales.shape
# Out:
# (36, 20)

# %%
hospitales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   WKT         36 non-null     object
#  1   ID          36 non-null     float64
#  2   NOMBRE      36 non-null     object
#  3   NOM_MAP     36 non-null     object
#  4   OBJETO      36 non-null     object
#  5   CALLE       36 non-null     object
#  6   ALTURA      36 non-null     int64
#  7   DOM_NORMA   36 non-null     object
#  8   DOM_GEO     36 non-null     object
#  9   TELEFONO    36 non-null     object
#  10  GUARDIA     34 non-null     object
#  11  FAX         35 non-null     object
#  12  WEB         13 non-null     object
#  13  COD_POSTAL  36 non-null     object
#  14  TIPO        36 non-null     object
#  15  TIPO_ESPEC  35 non-null     object
#  16  MOD_AT_1    35 non-null     object
#  17  MOD_AT_2    35 non-null     object
#  18  DEPEND_ADM  36 non-null     object
# ...

# %%
hospitales.loc[hospitales['GUARDIA'].isna()]
# Out:
#                                             WKT    ID
# 33  POINT (-58.4566428491103 -34.6718480140772)  36.0  \
# 35  POINT (-58.3814293381891 -34.6419888014928)   5.0
#
#                                                NOMBRE
# 33                          HOSPITAL CECILIA GRIERSON  \
# 35  TALLERES PROTEGIDOS DE REHABILITACION PSIQUIAT...
#
#                             NOM_MAP    OBJETO
# 33                   HOSP. GRIERSON  HOSPITAL  \
# 35  TALLERES DE REHAB. PSIQUIATRICA  HOSPITAL
#
#                                        CALLE  ALTURA
# 33  FERNANDEZ DE LA CRUZ, F., GRAL. AV. 4402    4402  \
# 35                                    SUAREZ    2215
#
#                                DOM_NORMA
# 33  FERNANDEZ DE LA CRUZ, F., GRAL. 4402  \
# 35                       SUAREZ AV. 2215
#
#                                  DOM_GEO   TELEFONO GUARDIA        FAX  WEB
# 33  4402 FERNANDEZ DE LA CRUZ, F., GRAL.  4604-9000     NaN        NaN  NaN  \
# ...

# %%
type(hospitales['WKT'][0])
# Out:
# str

# %%
ejemplo = hospitales['WKT'][0].split()

# %%
ejemplo
# Out:
# ['POINT', '(-58.3775508488443', '-34.6288473603881)']

# %%
ejemplo[1].strip('(')
# Out:
# '-58.3775508488443'

# %%
ejemplo[2].strip(')')
# Out:
# '-34.6288473603881'

# %%
coordenadas = [coordenadas.split() for coordenadas in hospitales['WKT']]

# %%
latitud = [float(elemento[1].strip('(')) for elemento in coordenadas]
longitud = [float(elemento[2].strip(')')) for elemento in coordenadas]
print(latitud[:5])
print(longitud[:5])
# Out:
# [-58.3775508488443, -58.4120700769456, -58.4027276547828, -58.3851559118889, -58.3913114406535]
# [-34.6288473603881, -34.5941919726393, -34.5845283357505, -34.6394041316484, -34.6341535760002]

# %%
hospitales.columns
# Out:
# Index(['WKT', 'ID', 'NOMBRE', 'NOM_MAP', 'OBJETO', 'CALLE', 'ALTURA',
#        'DOM_NORMA', 'DOM_GEO', 'TELEFONO', 'GUARDIA', 'FAX', 'WEB',
#        'COD_POSTAL', 'TIPO', 'TIPO_ESPEC', 'MOD_AT_1', 'MOD_AT_2',
#        'DEPEND_ADM', 'DIRECTOR'],
#       dtype='object')

# %%
hospitales['latitude'] = latitud
hospitales['longitude'] = longitud

# %%
hospitales.head()
# Out:
#                                            WKT   ID
# 0  POINT (-58.3775508488443 -34.6288473603881)  1.0  \
# 1  POINT (-58.4120700769456 -34.5941919726393)  2.0
# 2  POINT (-58.4027276547828 -34.5845283357505)  4.0
# 3  POINT (-58.3851559118889 -34.6394041316484)  6.0
# 4  POINT (-58.3913114406535 -34.6341535760002)  7.0
#
#                                               NOMBRE
# 0        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE  \
# 1        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
#
#                        NOM_MAP    OBJETO                    CALLE  ALTURA
# 0            HOSP. DE ELIZALDE  HOSPITAL  MANUEL A. MONTES DE OCA      40  \
# 1              HOSP. GUTIERREZ  HOSPITAL                    GALLO    1330
# 2  HOSP. ODONTOLOGICO CARRILLO  HOSPITAL    SANCHEZ DE BUSTAMANTE    2529
# ...

# %%
hospitales.rename(columns={'NOMBRE': 'label', 'DOM_NORMA': 'name'}, inplace=True)
hospitales.head()
# Out:
#                                            WKT   ID
# 0  POINT (-58.3775508488443 -34.6288473603881)  1.0  \
# 1  POINT (-58.4120700769456 -34.5941919726393)  2.0
# 2  POINT (-58.4027276547828 -34.5845283357505)  4.0
# 3  POINT (-58.3851559118889 -34.6394041316484)  6.0
# 4  POINT (-58.3913114406535 -34.6341535760002)  7.0
#
#                                                label
# 0        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE  \
# 1        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
#
#                        NOM_MAP    OBJETO                    CALLE  ALTURA
# 0            HOSP. DE ELIZALDE  HOSPITAL  MANUEL A. MONTES DE OCA      40  \
# 1              HOSP. GUTIERREZ  HOSPITAL                    GALLO    1330
# 2  HOSP. ODONTOLOGICO CARRILLO  HOSPITAL    SANCHEZ DE BUSTAMANTE    2529
# ...

# %%
hospitales = hospitales[['latitude', 'longitude', 'name', 'label']]
hospitales
# Out:
#      latitude  longitude                                  name
# 0  -58.377551 -34.628847          MONTES DE OCA, MANUEL AV. 40  \
# 1  -58.412070 -34.594192                            GALLO 1330
# 2  -58.402728 -34.584528            SANCHEZ DE BUSTAMANTE 2529
# 3  -58.385156 -34.639404                         BRANDSEN 2570
# 4  -58.391311 -34.634154                      CASEROS AV. 2061
# 5  -58.434943 -34.608472                   DIAZ VELEZ AV. 4821
# 6  -58.375843 -34.630211           FINOCHIETTO ENRIQUE DR. 849
# 7  -58.382328 -34.635702              CARRILLO, RAMON, DR. 315
# 8  -58.382128 -34.636435              CARRILLO, RAMON, DR. 375
# 9  -58.360120 -34.638892         DON PEDRO DE MENDOZA AV. 1795
# 10 -58.440988 -34.553896                        ECHEVERRIA 955
# 11 -58.402751 -34.634856                 LUCA, ESTEBAN DE 2151
# 12 -58.460186 -34.605434               JUSTO, JUAN B. AV. 4151
# 13 -58.427660 -34.614635                              MUÑIZ 15
# ...

# %%
hospitales.to_csv('hospitales_cleaned.csv',index=False)
